# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/2_Programacion_en_Python/7_Taller_Tuplas_Texto_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # Taller Programación en Python: Tuplas, Cadenas de Texto y Conjuntos
# ---

# %% [markdown]
# **IMPORTANTE**: Guarda una copia de este notebook en tu Google Drive o computador.

# %% [markdown]
# **Taller en parejas**

# %% [markdown]
# **Nombres estudiantes:**
#
# -Juan Pablo Sanchez Luis
# -David Ruiz

# %% [markdown]
# **Forma de entrega:**
#
# - Registrar las respuestas en https://forms.office.com/r/Uashdq5Gqa para obtener la calificación. Vale 25 puntos.
#
# - Publicar Jupyter Notebook con el desarrollo del taller en la cuenta de Github de uno de los estudiantes. Nombrar el archivo de la siguiente forma:“Taller_Tuplas_nombres_y_apellidos.ipynb”. Esto vale 5 puntos adicionales a las respuestas del formulario.
#
# Puntaje total del taller: 30 puntos.

# %% [markdown]
# **Plazo de entrega:**
#
# 10 de febrero de 2026, máximo a las 11:59 p.m. Tenga en cuenta que luego de esa hora el formulario en forms se cierra. El Jupupyter Notebook también debe quedar subido en Github antes de esa hora.

# %% [markdown]
# **Instrucciones Generales:**
#
# Completa el código en las celdas marcadas con `### TU CÓDIGO AQUÍ ###`. Puedes añadir más celdas si lo requieres.

# %% [markdown]
# ## 🔹 Parte I: Tuplas

# %% [markdown]
# ### Ejercicio 1:
# **Contexto:** Un bono soberano se define por su Emisor, Tasa Cupón y Años para el Vencimiento.
# **Tarea:** Crea una tupla llamada `bono` que contenga los siguientes datos: "Tesoro EEUU", 3.5 y 10, donde 3.5 corresponde a la tasa cupón y 10 al número de años.

# %%
### TU CÓDIGO AQUÍ ###
bono = ("Tesoro EEUU", 3.5, 10)
print(bono)
# Out:
# ('Tesoro EEUU', 3.5, 10)

# %% [markdown]
# ### Ejercicio 2:
# **Contexto:** Tienes una tupla con la inflación mensual: `(0.5, 0.8, 1.2, 0.4)`.
# **Tarea:** Extrae el valor del tercer mes (marzo) y guárdalo en una variable llamada `inflacion_marzo`.

# %%
inflacion_mensual = (0.5, 0.8, 1.2, 0.4)

# %%
### TU CÓDIGO AQUÍ ###
inflacion_marzo = inflacion_mensual[2]

print(inflacion_marzo)
# Out:
# 1.2

# %% [markdown]
# ### Ejercicio 3:
# **Contexto:** Tienes la tupla `datos_macro = (350.5, 360.2)`.
# **Tarea:** Desempaqueta la tupla en las variables `pib_real` y `pib_forecast`.

# %%
datos_macro = (350.5, 360.2)

# %%
### TU CÓDIGO AQUÍ ###
pib_real, pib_forecast = datos_macro

print(f"pib_real: {pib_real} ; pib_forecast: {pib_forecast}")
# Out:
# pib_real: 350.5 ; pib_forecast: 360.2

# %% [markdown]
# ### Ejercicio 4:
# **Contexto:** Tienes la tupla `precios_semana=(100, 102, 105, 103, 108)` con los precios de la acción de Google de lunes a viernes.
# **Tarea:** Crea la tupla `mitad_semana` con los precios de Miércoles, Jueves y Viernes únicamente (usa slicing).

# %%
precios_semana = (100, 102, 105, 103, 108)

# %%
### TU CÓDIGO AQUÍ ###
precios_semana = (100, 102, 105, 103, 108)

mitad_semana = precios_semana[2:5]

print(mitad_semana)
# Out:
# (105, 103, 108)

# %% [markdown]
# ### Ejercicio 5:
# **Tarea:** En la tupla `ratings`, cuenta cuántas 'AAA' hay y guarda el número en la variable `conteo_aaa`. Adicionalmente, encuentra el índice de la primera 'C' y guarda ese número en la variable `indice_c`.

# %%
ratings = ('A', 'AA', 'AAA', 'B', 'AAA', 'C', 'AAA')

# %%
### TU CÓDIGO AQUÍ ###
conteo_aaa = ratings.count('AAA')
indice_c = ratings.index('C')

print(f"conteo_aaa: {conteo_aaa} ; indice_c: {indice_c}")
# Out:
# conteo_aaa: 3 ; indice_c: 5

# %% [markdown]
# ### Ejercicio 6:
# **Contexto:** Un portafolio se estructura como `(Nombre_Fondo, (Activo1, Activo2, Activo3))`.
# **Tarea:** Extrae "GOOG" de la tupla anidada y guárdalo en la variable `activo_tec`.

# %%
portafolio = ("Tecnología", ("AAPL", "GOOG", "AMZN"))

# %%
### TU CÓDIGO AQUÍ ###
activo_tec = portafolio[1][1]
print(activo_tec)
# Out:
# GOOG

# %% [markdown]
# ## 🔹 Parte II: Cadenas de Texto (Strings)

# %% [markdown]
# ### Ejercicio 7:
# **Tarea:** Convierte `"$ 4.500"` en `"4.500"` quitando el signo pesos y el espacio. Guarda el precio limpio en la variable `precio_texto`.

# %%
precio_sucio = "$ 4.500"

# %%
### TU CÓDIGO AQUÍ ###
precio_texto = precio_sucio.replace("$", "").strip()
print(precio_texto)
# Out:
# 4.500

# %% [markdown]
# ### Ejercicio 8:
# **Tarea:** Convierte el texto `"Fecha,Producto,Precio"` en una lista llamada `columnas`.

# %%
linea_csv = "Fecha,Producto,Precio"

# %%
### TU CÓDIGO AQUÍ ###
columnas = linea_csv.split(",")
print(columnas)
# Out:
# ['Fecha', 'Producto', 'Precio']

# %% [markdown]
# ### Ejercicio 9:
# **Tarea:** Convierte el texto `"Col"` a `"COL"` y guardalo en la variable `pais_2`.

# %%
pais = "Col"

# %%
### TU CÓDIGO AQUÍ ###
pais_2 = pais.upper()
print(pais_2)
# Out:
# COL

# %% [markdown]
# ### Ejercicio 10:
# **Tarea:** Verifica si el siguiente número de cuenta de ahorros de un cliente empieza con `"2"`. Almacena el booleano en la variable `inicio`.

# %%
numero_cuenta = "230505"

# %%
### TU CÓDIGO AQUÍ ###
inicio = numero_cuenta.startswith("2")
print(inicio)
# Out:
# True

# %% [markdown]
# ### Ejercicio 11:
# **Tarea:** A partir de las variables indicador y valor, usa f-strings para imprimir la siguiente frase: "La inflación fue del 10.5%."

# %%
indicador = "inflación"
valor = 10.5

# %%
### TU CÓDIGO AQUÍ ###

frase= f"La {indicador} fue del {valor}%."

# %% [markdown]
# ### Ejercicio 12:
# **Contexto:** Analizas titulares de noticias.
# **Tarea:** Encuentra el índice (posición) donde empieza la palabra "Déficit". Guarda el número en la variable `posicion`.

# %%
titular = "Informe: El Déficit fiscal aumentó."

# %%
### TU CÓDIGO AQUÍ ###
posicion = titular.find("Déficit")

print(posicion)
# Out:
# 12

# %% [markdown]
# ### Ejercicio 13:
# **Contexto:** Análisis de sentimiento en reportes financieros.
# **Tarea:** Cuenta cuántas veces aparece la palabra "riesgo" en el siguiente texto y almacena el número en la variable `frecuencia`.

# %%
texto = "El mercado detecta un riesgo inminente de recesión. Los analistas temen que el riesgo inflacionario, sumado al riesgo cambiario, frene la inversión. Ante este escenario negativo, gestionar el riesgo sistémico es vital, pues ignorar cualquier riesgo crediticio ahora podría detonar una crisis bursátil severa e irreversible."

# %%
### TU CÓDIGO AQUÍ ###
frecuencia = texto.count("riesgo")
print(frecuencia)
# Out:
# 5

# %% [markdown]
# ### Ejercicio 14:
# **Contexto:** Tienes una lista de correos y necesitas enviarlos separados por punto y coma `;`.
# **Tarea:** Une la lista `emails` en un solo string separado por `;`. Almacena este string en la variable `lista_envio`.

# %%
emails = ["gerencia@banco.com", "analitica@banco.com", "mercadeo@banco.com", "finanzas@banco.com", "contabilidad@banco.com", "recursos_humanos@banco.com"]

# %%
### TU CÓDIGO AQUÍ ###
lista_envio = ";".join(emails)

print(lista_envio)
# Out:
# gerencia@banco.com;analitica@banco.com;mercadeo@banco.com;finanzas@banco.com;contabilidad@banco.com;recursos_humanos@banco.com

# %% [markdown]
# ### Ejercicio 15:
# **Contexto:** Validar si un ID ingresado contiene solo números.
# **Tarea:** Verifica si `id_input` es numérico o si contiene letras. Guarda el booleano en la variable `es_valido`.

# %%
id_input = "109845"

# %%
### TU CÓDIGO AQUÍ ###
es_valido = id_input.isnumeric()

print(es_valido)
# Out:
# True

# %% [markdown]
# ### Ejercicio 16:
# **Contexto:** Normalizar nombres de entidades.
# **Tarea:** Convierte el texto "ministerio de hacienda" a formato Título (Mayúscula inicial en cada palabra). Guarda el nuevo texto en la variable `entidad_fmt`.

# %%
entidad = "ministerio de hacienda"

# %%
### TU CÓDIGO AQUÍ ###
entidad_fmt = entidad.title()

print(entidad_fmt)
# Out:
# Ministerio De Hacienda

# %% [markdown]
# ### Ejercicio 17:
# **Contexto:** Un texto mal formateado trae guiones al inicio y final: `"---Datos---"`.
# **Tarea:** Elimina los guiones usando `strip("-")`. Almacena el resultado en la variable `dato_limpio`.

# %%
dato = "---Datos---"

# %%
### TU CÓDIGO AQUÍ ###
dato_limpio = dato.strip("-")

print(dato_limpio)
# Out:
# Datos

# %% [markdown]
# ### Ejercicio 18:
#
# **Tarea:** A partir de las variables nombre, edad y ciudad, usa f-strings para imprimir el siguiente mensaje: "Hola, Adriana. Tienes 23 años y vives en Bucaramanga." El texto debe guardarse en la variable `mensaje`.

# %%
nombre = "Adriana"
edad = 23
ciudad = "Bucaramanga"

# %%
### TU CÓDIGO AQUÍ ###
mensaje = f"Hola, {nombre}. Tienes {edad} años y vives en {ciudad}."

print(mensaje)
# Out:
# Hola, Adriana. Tienes 23 años y vives en Bucaramanga.

# %% [markdown]
# ## 🔹 Parte III: Conjuntos (Sets)

# %% [markdown]
# ### Ejercicio 19:
# **Tarea:** A continuación hay una lista de clientes, la cual contiene duplicados. Conviértela en un conjunto llamado `clientes_unicos` para eliminar las repeticiones.

# %%
transacciones = ["ClienteA", "ClienteB", "ClienteA", "ClienteC", "ClienteB"]

# %%
### TU CÓDIGO AQUÍ ###
clientes_unicos = set(transacciones)

print(clientes_unicos)
# Out:
# {'ClienteB', 'ClienteC', 'ClienteA'}

# %% [markdown]
# ### Ejercicio 20:
# **Contexto:** Hay dos conjuntos con el nombre de los clientes que hicieron compras en enero y febrero a la joyería "La Esmeralda". **Tarea:** Encuentra el nombre de los clientes que compraron en ambos meses. Almacena la respuesta en el conjunto `clientes_recurrentes`.

# %%
enero = {"Jorge", "Lucía", "Juan", "Ana", "Pedro"}
febrero = {"Ana", "Luis", "Juan", "Carlos"}

# %%
### TU CÓDIGO AQUÍ ###
clientes_recurrentes = enero.intersection(febrero)

print(clientes_recurrentes)
# Out:
# {'Ana', 'Juan'}

# %% [markdown]
# ### Ejercicio 21:
# **Contexto:** Los conjuntos `bodega_a` y `bodega_b` tienen registrado el inventario que hay en las dos bodegas de la empresa "Smart PC". **Tarea:** Crea un conjunto llamado `inventario_total`, el cual contenga todo el inventario de la empresa.

# %%
bodega_a = {"Laptop", "Mouse", "Pantalla"}
bodega_b = {"Teclado", "Mouse"}

# %%
### TU CÓDIGO AQUÍ ###
inventario_total = bodega_a.union(bodega_b)

print(inventario_total)
# Out:
# {'Laptop', 'Mouse', 'Teclado', 'Pantalla'}

# %% [markdown]
# ### Ejercicio 22:
# **Contexto:** La empresa "Multimuebles" tiene dos bases de datos con los clientes que le compraron muebles de oficina en 2022 y 2023 y desea saber qué clientes compraron en 2022 y no compraron en 2023. **Tarea:** Encuentra los clientes de 2022 que NO están en 2023 y guarda la respuesta en el conjunto `clientes_perdidos`.

# %%
base_2022 = {"Empresa X", "Empresa Y", "Empresa Z"}
base_2023 = {"Empresa X", "Empresa Z"}

# %%
### TU CÓDIGO AQUÍ ###
clientes_perdidos = base_2022.difference(base_2023)

print(clientes_perdidos)
# Out:
# {'Empresa Y'}

# %% [markdown]
# ### Ejercicio 23: Diferencia Simétrica
# **Contexo:**. Una empresa inversionista tiene dos portafolios y desea saber cuáles activos son exclusivos de cada portafolio (no se comparten). **Tarea:** Crea el conjunto activos_exclusivos para responder la duda de la empresa.

# %%
portafolio_a = {"AAPL", "TSLA", "GOOG"}
portafolio_b = {"MSFT", "GOOG", "AMZN"}

# %%
### TU CÓDIGO AQUÍ ###
activos_exclusivos = portafolio_a.symmetric_difference(portafolio_b)

print(activos_exclusivos)
# Out:
# {'MSFT', 'AAPL', 'AMZN', 'TSLA'}

# %% [markdown]
# ### Ejercicio 24:
# **Tarea:** Agrega "Costa Rica" al conjunto de países de la OCDE.

# %%
paises_ocde = {"Colombia", "Chile", "México"}

# %%
### TU CÓDIGO AQUÍ ###
paises_ocde.add("Costa Rica")

print(paises_ocde)
# Out:
# {'Costa Rica', 'México', 'Chile', 'Colombia'}

# %% [markdown]
# ### Ejercicio 25: Pipeline de Limpieza (List -> Set -> List)
# **Contexto:** Tienes una lista de precios con duplicados y desordenada. Quieres una lista limpia y ordenada.
# **Tarea:**
# 1. Convierte la lista `precios_raw` a set para quitar duplicados.
# 2. Convierte ese set de nuevo a lista con list().
# 3. Ordena la lista resultante usando sorted().
# Guarda el resultado final en `precios_limpios`.

# %%
precios_raw = [100, 200, 100, 50, 200]

# %%
### TU CÓDIGO AQUÍ ###
precios_limpios = list(set(precios_raw))
precios_limpios.sort()

print(precios_limpios)
# Out:
# [50, 100, 200]

# %% [markdown]
# Ejecuta esta celda al finalizar todo el taller. Si no obtienes ningún error, ¡felicidades! Tu lógica es correcta. Si obtienes un mensaje de error en la validación, revisa los puntos indicados.

# %%
def verificar_taller():
    errores = []

    try:
        if not (isinstance(bono, tuple) and len(bono) == 3 and (bono[1] * 2 == 7.0)):
            errores.append("1")
        if not (inflacion_marzo ** 2 == 1.44):
            errores.append("2")
        if not (pib_real + pib_forecast == 710.7):
            errores.append("3")
        if not (sum(mitad_semana) == 316 and len(mitad_semana) == 3):
            errores.append("4")
        if not (conteo_aaa * 2 == 6 and indice_c + 1 == 6):
            errores.append("5")
        if not (len(activo_tec) == 4 and activo_tec.startswith("G")):
            errores.append("6")
        if not (precio_texto.replace(".", "").isdigit() and len(precio_texto) == 5):
            errores.append("7")
        if not (len(columnas) == 3 and "Producto" in columnas):
            errores.append("8")
        if not (len(pais_2) == 3 and pais_2.isupper()):
            errores.append("9")
        if not (inicio is True):
            errores.append("10")
        if not ("10.5%" in frase and "inflación" in frase):
            errores.append("11")
        if not (posicion == (2**2 * 3)):
            errores.append("12")
        if not (frecuencia == (25 // 5)):
            errores.append("13")
        if not (lista_envio.count(";") == 5):
            errores.append("14")
        if not (es_valido is True):
            errores.append("15")
        if not (entidad_fmt == "Ministerio De Hacienda"):
            errores.append("16")
        if not (len(dato_limpio) == 5):
            errores.append("17")
        if not ("Bucaramanga" in mensaje and "23" in mensaje):
            errores.append("18")
        if not (len(clientes_unicos) == 3 and isinstance(clientes_unicos, set)):
            errores.append("19")
        if not (len(clientes_recurrentes) == 2 and "Ana" in clientes_recurrentes):
            errores.append("20")
        if not (len(inventario_total) == 4):
            errores.append("21")
        if not (len(clientes_perdidos) == 1 and "Empresa Y" in clientes_perdidos):
            errores.append("22")
        if not ("GOOG" not in activos_exclusivos and len(activos_exclusivos) == 4):
            errores.append("23")
        if not ("Costa Rica" in paises_ocde):
            errores.append("24")
        if not (precios_limpios == sorted([100, 200, 50])):
            errores.append("25")

    except NameError as e:
        errores.append(f"Variable no definida: {e.name}")

    # Resultado Final
    if not errores:
        print("✅ ¡Felicidades! Todos los ejercicios son correctos. Taller completado con éxito.")
    else:
        print(f"❌ Se encontraron inconsistencias en los siguientes puntos: {', '.join(errores)}")
        print("Revisa tu lógica, el nombre de las variables y los formatos solicitados e intenta nuevamente.")

verificar_taller()
# Out:
# ✅ ¡Felicidades! Todos los ejercicios son correctos. Taller completado con éxito.
